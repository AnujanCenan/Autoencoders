# %%
import sys
from pathlib import Path
import numpy as np

notebook_dir = Path().resolve()

data_reader_path = notebook_dir.parent/"data_reader"
pre_processor_path = notebook_dir.parent/"pre_processing"
plotter_path = notebook_dir.parent/"plotter"

if str(data_reader_path) not in sys.path:
    sys.path.append(str(data_reader_path))

if str(pre_processor_path) not in sys.path:
    sys.path.append(str(pre_processor_path))

if str(plotter_path) not in sys.path:
    sys.path.append(str(plotter_path))

# %% [markdown]
# ## Autoencoder Architecture
#
# Contains all information regarding overall architecture used and the loss function (see the training step).
# See **feature_extractor.py**

# %% [markdown]
# ## Training
#
# Based on the architecture and the data, we train a model

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model

import numpy as np
import os
from dotenv import load_dotenv

from feature_extractor import Feature_Extractor


load_dotenv()

X_train = np.load(os.getenv("V6_TRAINING_DATA"))

print(X_train.shape)        # Output: (69878, 1024)
if len(X_train.shape) == 2:
    X_train = np.expand_dims(X_train, axis=-1)

model = Feature_Extractor()

optimizer = tf.keras.optimizers.Adam(
    learning_rate=0.001, 
    beta_1=0.9, 
    beta_2=0.999
)

model.compile(optimizer=optimizer)
        
model.fit(X_train, epochs=2000, batch_size=32)

model.save_weights("v6_compression_paper.weights.h5")
# Out:
# (69878, 1024)
# Epoch 1/2000
#  121/2184 ━━━━━━━━━━━━━━━━━━━━ 38s 18ms/step - l1: 0.0000e+00 - loss: 0.0330 - mse: 0.0330
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 29
#      21 optimizer = tf.keras.optimizers.Adam(
#      22     learning_rate=0.001,
#      23     beta_1=0.9,
#      24     beta_2=0.999
#      25 )
#      27 model.compile(optimizer=optimizer)
# ---> 29 model.fit(X_train, epochs=2000, batch_size=32)
#      31 model.save_weights("v6_compression_paper.weights.h5")
#
# File ~/Documents/Studying/Year 4/Term 1/Thesis A/Mini-Projects/Autoencoders/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
# ...
